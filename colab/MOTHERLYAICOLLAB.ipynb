# %%
import pandas as pd
df = pd.read_csv('journal_entries.csv')[['Entry','Emotion']].dropna()

# %%
import pandas as pd
df = pd.read_csv('journal_entries.csv')[['Entry','Emotion']].dropna()

# %%
# !pip install transformers sentence-transformers faiss-cpu pandas

# %%
from google.colab import files
files.upload()  # upload your downloaded Kaggle CSVs
